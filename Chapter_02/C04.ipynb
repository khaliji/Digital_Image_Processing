# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the image in greyscale
img = np.array(cv2.imread("yard.jpg", cv2.IMREAD_GRAYSCALE), dtype=np.uint8)
p = cv2.normalize(src=img, dst=None, alpha=0.0, beta=1.0, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

gamma = 0.8
# gamma correction formula is: q = p ^ (1/gamma)
q = norm_img **((1.0)/ gamma)

fig, axes= plt.subplots(1, 2, figsize=(18, 18))
axes[0].imshow(img, 'gray')
axes[0].set_title('orginal image')

axes[1].imshow(q, 'gray')
axes[1].set_title('enhanced image')

# remove the x and y ticks
for i in range(axes.shape[0]):
    axes[i].set_xticks([])
    axes[i].set_yticks([])
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()
