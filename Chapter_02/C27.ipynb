# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.array(cv2.imread("jungle.png", cv2.IMREAD_GRAYSCALE))

alpha = 0.2
kernel = (1/(alpha+1))* np.array([[-alpha, alpha - 1, -alpha],
                  [alpha - 1, alpha + 5, alpha - 1],
                  [-alpha, alpha - 1, -alpha]])
Ip = cv2.filter2D(img, -1, kernel, borderType=cv2.BORDER_REPLICATE)

fig, axes= plt.subplots(1, 2, figsize=(12, 5))
axes[0].imshow(imgd, cmap='gray')
axes[0].set_title('original image')

axes[1].imshow(Ip, cmap='gray')
axes[1].set_title('sharpped image')

for ax in axes.ravel():
    ax.set_xticks([])
    ax.set_yticks([])

cv2.waitKey(0)
cv2.destroyAllWindows()
