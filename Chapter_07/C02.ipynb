# %%
import cv2
from matplotlib import pyplot as plt
import pywt

# %%
img = cv2.imread(filename="azadi_tower.jpg")
n = 'sym4'
coeffs = pywt.dwt2(img, wn)
CA, (CV, CH, CD) = coeffs
ReImg = pywt.idwt2(coeffs, wn)
plt.imshow(ReImg.astype("uint8"))
plt.xticks([])
plt.yticks([])
plt.show()
