# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
[x, y] = np.meshgrid(np.array(range(-128,128)), np.array(range(-128,128)))
R = 30
n = 2
D = np.sqrt(x**2 + y**2)
H = 1/(1 + (D/R)**(2*n))
H1 = 1-H

plt.imshow(H1, cmap='gray', vmin=np.min(H), vmax=np.max(H))
plt.title('Butterworth high pass filter')
plt.xticks([]), plt.yticks([])

plt.show()
